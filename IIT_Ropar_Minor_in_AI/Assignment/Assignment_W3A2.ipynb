# %% [markdown]
# <a href="https://colab.research.google.com/github/shivamsingh163248/IIT-Ropar-Minor-in-AI/blob/main/IIT_Ropar_Minor_in_AI/Assignment/Assignment_W3A2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: WRITE A CODE OF ALL THE CODITION FOR LIST MANUPULATION AND ITARAION AND SEATCHING

# List Manipulation and Iteration

# Creating lists
my_list = [1, 2, 3, 4, 5]
empty_list = []
mixed_list = [1, "hello", 3.14, True]


# Accessing elements
first_element = my_list[0]  # Accessing the first element (index 0)
last_element = my_list[-1] # Accessing the last element


# Slicing
sub_list = my_list[1:4]  # Elements from index 1 up to (but not including) index 4
first_three = my_list[:3]  # Elements from the beginning up to (but not including) index 3
last_two = my_list[-2:]  # Elements from the second to last element to the end


# Modifying elements
my_list[0] = 10  # Changing the first element


# Adding elements
my_list.append(6)  # Adding an element to the end
my_list.insert(2, 7)  # Inserting an element at a specific index


# Removing elements
my_list.remove(3)  # Removing the first occurrence of a value
removed_element = my_list.pop(0)  # Removing and returning an element at a specific index
del my_list[1] # Removing an element at a specific index
my_list.clear() # Removing all elements


# List operations
list1 = [1, 2, 3]
list2 = [4, 5, 6]
combined_list = list1 + list2  # Concatenating two lists
repeated_list = list1 * 3  # Repeating a list


# Iterating through a list

# Using a for loop
for item in my_list:
    print(item)

# Using a for loop with index
for i in range(len(my_list)):
    print(f"Element at index {i}: {my_list[i]}")

# Using enumerate
for index, item in enumerate(my_list):
    print(f"Element at index {index}: {item}")


# List comprehensions
squares = [x**2 for x in range(1, 6)]
even_numbers = [x for x in my_list if x % 2 == 0]


# Searching in a list

# Using the 'in' operator
if 5 in my_list:
    print("5 is in the list")

# Using the index() method
try:
  index_of_3 = my_list.index(3) # Returns the index of the first occurance
  print(f"The index of 3 is: {index_of_3}")
except ValueError:
  print("3 is not in the list")

# Counting occurrences
count_of_3 = my_list.count(3)


# Other useful methods
my_list.sort()  # Sorting the list in-place
my_list.reverse()  # Reversing the list in-place
new_list = my_list.copy() # Creating a copy of the list
list_length = len(my_list)  # Getting the length of the list

# Example illustrating common operations:
my_list = [1, 2, 3, 4, 5]
print("Original List:", my_list)
my_list.append(6)
print("Appended 6:", my_list)
my_list.insert(2, 7)
print("Inserted 7 at index 2:", my_list)
my_list.remove(3)
print("Removed 3:", my_list)

# Example of a list comprehension
even_numbers = [num for num in my_list if num % 2 == 0]
print("Even numbers from the list:", even_numbers)
