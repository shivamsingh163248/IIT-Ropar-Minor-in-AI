# %% [markdown]
# <a href="https://www.kaggle.com/code/shivamsingh163248/linearregression-implementation?scriptVersionId=247889643" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
#design and developd by shivam_singh #shivamsingh163248
