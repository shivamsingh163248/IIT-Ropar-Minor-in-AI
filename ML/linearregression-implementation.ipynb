# %% [markdown]
# <a href="https://www.kaggle.com/code/shivamsingh163248/linearregression-implementation?scriptVersionId=248026802" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# Step 1: Import libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# Step 2: Load the dataset from the Kaggle input path
housing = pd.read_csv('/kaggle/input/housing-prices-dataset/Housing.csv')

# %%
housing.tail()
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 540  1820000  3000         2          1        1      yes        no      yes
# 541  1767150  2400         3          1        1       no        no       no
# 542  1750000  3620         2          1        1      yes        no       no
# 543  1750000  2910         3          1        1       no        no       no
# 544  1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 540              no              no        2       no      unfurnished
# 541              no              no        0       no   semi-furnished
# 542              no              no        0       no      unfurnished
# 543              no              no        0       no        furnished
# 544              no              no        0       no      unfurnished

# %%
housing.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
housing.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
area = housing['area']
prise = housing['price']
#now reshaping the elemet for the put in the fit function in the liner regreesion
x = np.array(area).reshape(-1 ,1)
y = np.array(prise).reshape(-1 , 1)
x_train , x_test , y_train ,  y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# Step 1: Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt  # For plotting
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Step 2: Load the dataset
housing = pd.read_csv('/kaggle/input/housing-prices-dataset/Housing.csv')

# Step 3: Select feature and target
x = housing[['area']]   # Feature
y = housing[['price']]  # Target

# Step 4: Train-test split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Step 5: Train the Linear Regression model
model = LinearRegression()
model.fit(x_train, y_train)

# Step 6: Predictions
y_pred = model.predict(x_test)

# Step 7: Evaluation metrics
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Step 8: Print results
print("\n📊 Regression Metrics:")
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
print("Mean Absolute Error (MAE):", mae)
print("R² Score (R2):", r2)

print("\n📈 Model Parameters:")
print("Coefficient (slope):", model.coef_[0][0])
print("Intercept:", model.intercept_[0])

# Step 9: Plotting Scatter Plot with Regression Line
plt.figure(figsize=(10, 6))
plt.scatter(x_test, y_test, color='blue', label='Actual Data')
plt.plot(x_test, y_pred, color='red', linewidth=2, label='Regression Line')
plt.xlabel('Area')
plt.ylabel('Price')
plt.title('Area vs Price - Linear Regression')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 📊 Regression Metrics:
# Mean Squared Error (MSE): 3675286604768.1855
# Root Mean Squared Error (RMSE): 1917103.7021424235
# Mean Absolute Error (MAE): 1474748.1337969352
# R² Score (R2): 0.27287851871974633
#
# 📈 Model Parameters:
# Coefficient (slope): 425.72984193878284
# Intercept: 2512254.2639593435
